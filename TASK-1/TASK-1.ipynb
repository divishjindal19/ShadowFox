# %% [markdown]
# # Visualization Library Documentation Guide: Matplotlib & Seaborn

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is a foundational plotting library in Python, providing control over every aspect of a figure. It is ideal for creating static, high-quality 2D plots.
#
# Suitable for publication-quality figures, detailed customization, and compatibility with many scientific libraries.

# %% [markdown]
# Line Plot
#
# Use Case: Visualizing trends over time or ordered data.

# %%
## Line Plot

import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.title("Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %% [markdown]
# Scatter Plot
#
# Use Case: Showing relationships between two variables.

# %%
x = [5, 7, 8, 7, 2, 17]
y = [99, 86, 87, 88, 100, 86]
plt.scatter(x, y)
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Bar Chart
#
# Use Case: Comparing categories.

# %%
x = ['A', 'B', 'C']
y = [10, 20, 15]
plt.bar(x, y)
plt.title("Bar Chart")
plt.show()

# %% [markdown]
# Histogram
#
# Use Case: Understanding distribution of a dataset.

# %%
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.title("Histogram")
plt.show()

# %% [markdown]
# Pie Chart
#
# Use Case: Displaying proportions.

# %%
sizes = [15, 30, 45, 10]
labels = ['A', 'B', 'C', 'D']
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# Built on top of Matplotlib, Seaborn simplifies the creation of beautiful and informative statistical graphics.
#
# Great for statistical data visualization, integrated with Pandas DataFrames, and aesthetically pleasing defaults.

# %% [markdown]
# Line Plot
#
# Use Case: Time series or sequential data with confidence intervals.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
data = pd.DataFrame({'x': np.arange(100), 'y': np.random.randn(100)})
sns.lineplot(x='x', y='y', data=data)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Scatter Plot
#
# Use Case: Exploring relationships in statistical data.

# %%
iris = sns.load_dataset('iris')
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# Bar Plot
#
# Use Case: Comparing categorical values with error bars.

# %%
tips = sns.load_dataset('tips')
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Histogram / Distribution Plot
#
# Use Case: Viewing distribution of numeric data.

# %%
sns.histplot(data=tips['total_bill'], bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# Box Plot
#
# Use Case: Visualizing spread and outliers in numerical data.

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Plotly

# %% [markdown]
# Plotly is a versatile graphing library known for creating interactive and web-based visualizations with ease.
#
# Ideal for dashboards, interactive reports, and presentations.

# %% [markdown]
# Line Plot
#
# Use Case: Interactive trend analysis.

# %%
import plotly.express as px
df = px.data.gapminder().query("country=='India'")
fig = px.line(df, x='year', y='gdpPercap', title='GDP Per Capita')
fig.show()

# %% [markdown]
# Scatter Plot
#
# Use Case: Interactive relationships with hover info.

# %%
df = px.data.iris()
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species')
fig.show()

# %% [markdown]
# Bar Chart
#
# Use Case: Category comparison with tooltips.

# %%
df = px.data.tips()
fig = px.bar(df, x='day', y='total_bill', color='sex', barmode='group')
fig.show()

# %% [markdown]
# Histogram
#
# Use Case: Visualizing frequency distribution interactively.

# %%
fig = px.histogram(df, x='total_bill')
fig.show()

# %% [markdown]
# Pie Chart
#
# Use Case: Proportional data with labels.

# %%
fig = px.pie(df, names='day', values='total_bill')
fig.show()

# %% [markdown]
# # Bokeh

# %% [markdown]
# Bokeh specializes in interactive, web-friendly plots that can be easily embedded in web apps.
#
# Perfect for real-time data visualization and browser-based interactivity.

# %% [markdown]
# Line Plot
#
# Use Case: Interactive line chart with zoom and pan.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
p = figure(title='Line Plot')
p.line([1, 2, 3, 4], [4, 7, 1, 6])
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f9aaa802-08ac-47da-8549-97ea7c914451">Loading BokehJS ...</span>
#     </div>
#   <div id="bb6c87c6-736b-4442-8d7e-50ea21c16f77" data-root-id="p1237" style="display: contents;"></div>

# %% [markdown]
# Scatter Plot
#
# Use Case: Interactive point cloud.

# %%
p = figure(title="Scatter Plot")
p.circle([1, 2, 3, 4], [4, 7, 1, 6], size=10, color="navy", alpha=0.5)
show(p)
# Out:
# ...
#   <div id="e6bbf8a4-e3f5-4b1b-9de8-0cc3b05c463f" data-root-id="p1281" style="display: contents;"></div>

# %% [markdown]
# Bar Chart
#
# Use Case: Simple bar chart visualization.

# %%
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource
source = ColumnDataSource(data=dict(fruits=['Apples', 'Oranges', 'Pears'], counts=[5, 3, 4]))
p = figure(x_range=source.data['fruits'], title="Bar Chart")
p.vbar(x='fruits', top='counts', width=0.5, source=source)
show(p)
# Out:
#   <div id="db8b76ce-d857-41b8-8c9f-b0eb88a31937" data-root-id="p1328" style="display: contents;"></div>

# %% [markdown]
# Histogram
#
# Use Case: Data distribution.

# %%
import numpy as np
hist, edges = np.histogram(np.random.normal(0, 1, 1000), bins=20)
p = figure(title="Histogram")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], fill_color="navy")
show(p)
# Out:
#   <div id="bb5d7bfc-0775-4435-9957-71161fcf0baa" data-root-id="p1373" style="display: contents;"></div>

# %% [markdown]
# Pie Chart
#
# Use Case: Bokeh doesn’t natively support pie charts, but can be created using wedge() glyph.

# %%
from math import pi
from bokeh.palettes import Category20c
from bokeh.transform import cumsum
import pandas as pd
x = {'A': 10, 'B': 20, 'C': 30, 'D': 40}
data = pd.Series(x).reset_index(name='value').rename(columns={'index': 'category'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]
p = figure()
p.wedge(x=0, y=1, radius=0.4, 
        start_angle=cumsum('angle', include_zero=True), 
        end_angle=cumsum('angle'), line_color='white', fill_color='color', legend_field='category', source=data)
show(p)
# Out:
#   <div id="e142b65f-6076-4b62-82e8-466d5a33bd84" data-root-id="p1420" style="display: contents;"></div>

# %% [markdown]
# # Comparison

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Resources
#
# Matplotlib:https://matplotlib.org/stable/users/explain/quick_start.html#quick-start
#
# Seaborn-https://seaborn.pydata.org/tutorial/introduction.html
#
# Plotly-https://plotly.com/python/distplot/
#
# Bokeh:https://docs.bokeh.org/en/latest/docs/user_guide/basic.html
